# %%
import requests
from bs4 import BeautifulSoup
import dateutil.parser as parser
import time
import parser
from urllib.parse import urlparse
class News:
    Article = ''
    Title = ''
    Author = ''
    OriginalContent = ''
    CreatedDate = ''
    FetchedDate = ''
    ArticleUrl = ''
    LastUsed = ''
    
    def __init__(self, article , title , author , originalcontent , createddate , fetcheddate , articleurl , lastused ):
        self.Article = article
        self.Title = title
        self.OriginalContent = originalcontent
        self.CreatedDate = createddate
        self.FetchedDate = fetcheddate
        self.ArticleUrl = articleurl
        self.LastUsed = lastused
        self.Author = author
        
def scraping(href):
    headers = {'user-agent' : 'Mozilla/5.0'}
    try:
        source = requests.get(href, headers = headers)
#         print (source)
        if source.status_code == 200:
            if (BeautifulSoup(source.content, "lxml")):
                soup = BeautifulSoup(source.content, "lxml").body 
                news = News(None, None, None, None, None, None, None, None)

                date = time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time()))
                news.fetchedDate = date
                news.lastUsed = date 
                news.articleUrl = href

               
                content = soup
                scrape_details(content,news)

                print ('URL********************************************************')
                print (news.articleUrl)
                print ('TITLE********************************************************')
                print (news.title)
                print ('DATE********************************************************')
                print (news.createdDate)
                print ('AUTHOR********************************************************')
                print (news.author)
                print ('ARTICLE********************************************************')
                print (news.article) 
            else:
                print ('can not get the information!')
        else:
            print ('Response is not 200!')
    except:
        print ('can not connect to the web page!')
              

def scrape_details(content, news):  
    news.content = content
    class_list_title = [
                'ArticleHeader_headline_2zdFM',
                'articleheader',
                'article-title',
                'ArticleHeader__hed___GPB7e',
                'entry-title',
                'entry-title single-title',
                'col-lg-9 col-md-8',
                'content__headline',
                'title',
                'name post-title entry-title',
                'articleTitle',
                'artTitle',
                'blog-title',
                'b-item__title',
                'postarea',
                'full-page-article left-col',
                'headline',
                'post_title',
                'post-title',
                'post-title entry-title',
                'post-headline',
                'pg-headline',
                'page-header',
                'content-header ',
                'field-subhead',
                '_8UFs4BVE',
                'the-title',
                'single-title',
                'story-title',
                'story-body__h1',
                'xxlarge',
                'row',
                'lede-text-only__hed'
            ] 
    for i in range(len(class_list_title)):
        if (content.find('',{'class':class_list_title[i]})):
#             print (class_list_title[i])
            news.title = content.find('',{'class':class_list_title[i]}).text         
            break
        else:
            news.title = None

    class_list_paragraph = [
                'ArticleBody__articleBody___1GSGP',
                'art-postcontent',
                'articles2',
                'article-inner',
                'article-text',                    
                'article-content',
                'article-copy',
                'article_body',
                'article section',
                'articleContentData',
                'article',
                'ArticleBody_body_2ECha',
                'b-item__description',
                'blog-content clearfix',
                'blog-content',
                'body-copy',
                'content-main',
                'content-text', 
                'cb-entry-content clearfix',
                'content__article-body from-content-api js-article__body',
                'content',
                'entry-content clearfix',
                'entry-content full-content',
                'entry clearfix',        
                'entry-content', 
                'entry_content',
                'entry-content print-only',
                'entry-body',
                'entry',                                       
                'entry entry-content',
                'event-text',
                'entry-meta',
                'entry-content-text',
                'field-item even',
                'field-items',
                'field-body',
                'infopage-news',
                'inner-post-entry',
                'td-post-content', 
                'the-content cf',
                'thecontent',
                'text-wrapper',
                'td-post-content td-pb-padding-side',
                'ntText',  
                'new_block',
                'post-single',                     
                'post-content entry-content cf',   
                'post-body entry-content',        
                'post_entry',
                'post_content',
                'post-body',
                'post-content clearfix', 
                'post-bodycopy clearfix',
                'post-single-content box mark-links',
                'post-content',
                'post-9141 post type-post status-publish format-standard has-post-thumbnail hentry category-world tag-fake-news tag-featured tag-satire',
                'vw-post-content clearfix',
                'wpb_wrapper',
                'single-box clearfix entry-content',
                'story-body story-body-1',
                'story-content',
                'story-body__inner',
                'sqs-block-content',
                'single single-post postid-193191 single-format-standard',
                'left relative',
                'l-container',
                'metadata__byline__author',
                'mainContent',
                'mk-single-content clearfix',
                'mvp-post-content-in',
                'group-container ',
                'group-container last',
                'el__leafmedia el__leafmedia--sourced-paragraph'
    ]

    news.article = []
    for i in range(len(class_list_paragraph)):
        if (content.find('',{'class': class_list_paragraph[i]})): 
#             print (class_list_paragraph[i])
            paragraphs = content.find('',{'class': class_list_paragraph[i]})
            if (paragraphs.findAll('p')):
                for paragraph in paragraphs.findAll('p'):
                    news.article.append(paragraph.text)
                break
            elif(paragraphs.findAll('',{'class': 'zn-body__paragraph speakable'})):
                for paragraph in paragraphs.findAll('',{'class': 'zn-body__paragraph speakable'}):
                    news.article.append(paragraph.text)               
        else:    
            news.article = []

    class_list_author = [
                'postmetadata',
                'author-article-link',
                'author-section',
                'ArticleHeader_byline_1VRIx',
                'field-author',
                'field-items',
                'fn',
                'name',
                'url fn n',
                'author vcard',
                'author left-edge',
                'author has-bio',
                'author',
                'artAuthor',
                'post-author',
                'post_author',
                'meta pf-author',
                'meta-author',
                'meta-holder',
                'mk-author-name',
                'author-name vcard fn',
                'text font-accent color-brand size-1x-small _1HynphR0',
                'theauthor',
                'byline-author',
                'byline__name',
                'byline',
                'blog-author',
                'createdby',
                'cb-author',
                'username',
                'single-author',
                'small',
                'entry-author-name',
                'metadata__byline__author'
    ]

    for i in range(len(class_list_author)):
        if (content.find('',{'class': class_list_author[i]})):
#             print (class_list_author[i])
            news.author = content.find("",{'class':class_list_author[i]}).text 
            break
        else:
            news.author = None


    class_list_date = [
                'timestamp',
                'entry-date published',
                'entry-date published updated',
                'content-published-mobile',
                'entry-date',
                'entry-meta',
                'entry-meta-content',
                'entry-meta-date updated',
                'byline byline-left ',
                'bydate',
                'blog-date',
                'b-item__asked-by-time',
                'pub_date',
                'post-date',
                'post_date',
                'post-date updated',               
                'time',
                'published', 
                'article-details',
                'article-timestamp',
                'art-postheadericons art-metadata-icons',
                'article_date',
                'ArticleHeader_date_V9eGk',
                'ArticleTimestamp__timestamp___1klks',
                'artData',
                'cb-date',
                'field-post-date',
                'fa fa-clock-o',
                'update-time',
                'row text font-accent size-1x-small color-darker-gray',
                'dateline',
                'datestamp',
                'date',
                'dt-published date-callout',
                'content__dateline-lm js-lm u-h',
                'grDate',
                'submitted',
                'single-date',
                'mk-publish-date',
                'relative ',
    ]

    for i in range(len(class_list_date)):
        if (content.find('',{'class': class_list_date[i]})):
#             print(class_list_date[i])
            news.createdDate = content.find('',{'class': class_list_date[i]})
#             print (news.createdDate['datetime'])
            try:
                news.createdDate = (parser.parse(news.createdDate['datetime'])).isoformat()
            except:
                try:
                    news.createdDate = (parser.parse(news.createdDate.text)).isoformat()
                except:
                    news.createdDate = None
            break
        else:
            news.createdDate = None

    return
# RELIABLE:
# link = 'http://www.bbc.com/news/uk-northern-ireland-40768202'
# link = 'http://www.abc.net.au/news/2017-07-24/top-water-bureaucrat-offered-confidential-documents-to-lobbyists/8738568'
# link = 'https://www.theguardian.com/us-news/2017/jul/21/sean-spicer-resigns-press-secretary-trump-white-house-feud'
# link = 'http://www.reuters.com/article/us-usa-trump-russia-lawyer-exclusive-idUSKBN1A61LZ'
# link = 'http://www.thedailysheeple.com/ex-nasa-scientist-claims-ufos-are-hiding-in-saturns-rings_072017'
# link = 'https://www.nytimes.com/2017/07/20/arts/music/chester-bennington-linkin-park-dead.html'
# link = 'http://time.com/4867932/donald-trump-investigate-robert-mueller-aides/'
# link = 'http://edition.cnn.com/2017/07/31/opinions/trump-reaction-north-korea-cristol-opinion/index.html'
# link = 'http://edition.cnn.com/2017/07/31/sport/caeleb-dressel-michael-phelps-mark-foster-swimming-world-championships/index.html'
# link = 'http://www.independent.co.uk/news/world/americas/russian-lawyer-donald-trump-jr-natalia-veselnitskaya-fsb-client-moscow-intelligence-agency-kremlin-a7853251.html'
# link = 'https://www.usatoday.com/story/news/politics/2017/07/27/obamacare-repeal-debate-show-votes-skinny-repeal/516423001/'
# link = 'https://www.bloomberg.com/news/articles/2017-08-01/brits-can-wave-summer-goodbye-as-southern-europe-set-to-swelter'
# link = 'https://www.cnbc.com/2017/07/31/reserve-bank-of-australia-monetary-policy-decision.html'
# link = 'http://www.abc.net.au/news/2017-08-01/who-is-the-typical-investor-in-the-australian-property-market/8764504'
# link = 'http://www.reuters.com/article/us-usa-trump-idUSKBN1AG1OV'
link = 'https://www.nytimes.com/2017/08/01/opinion/trump-democracy-institutions-destroyed.html?action=click&pgtype=Homepage&clickSource=story-heading&module=opinion-c-col-left-region&region=opinion-c-col-left-region&WT.nav=opinion-c-col-left-region'
# FAKE:
# link = 'http://www.thedailysheeple.com/astronomers-detect-strange-radio-signals-from-nearby-star_072017'
# link = 'http://awm.com/will-this-latest-blunder-be-the-final-nail-in-the-coffin-for-the-worst-show-in-tv-history/?utm_medium=homepage&utm_source=homepage1'
# link = 'http://americannews.com/beware-new-doll-meant-indoctrinate-sharia-law-children-coming-home/'
# link = 'http://alternativemediasyndicate.com/2017/07/12/citizens-right-defend-police-brutality/'
# link = 'http://www.bostonleader.com/us-regulator-warns-consumers-of-fire-hazard-from-samsung-phones/'
# link = 'http://gatesofvienna.net/2017/07/gates-of-vienna-news-feed-7262017/'
# BIAS
# link = 'http://www.americanthinker.com/articles/2017/07/europe_downward_now_the_bavarians_want_to_leave.html'
# link = 'http://100percentfedup.com/watch-rep-steve-kings-bombshell-answer-trumps-wall-hasnt-built-yet-video/'
# link = 'https://www.ammoland.com/2017/07/cheetah-12-shotgun-review/#axzz4npPZrytk'
# link = 'http://www.charismanews.com/opinion/66433-exactly-how-many-items-have-been-checked-off-on-jesus-end-times-list'
# link = 'http://endingthefed.com/report-obama-to-free-gitmo-detainees-who-have-vowed-to-behead-americans.html'
# link = 'http://conservativehq.com/node/26138'
# link = 'http://www.dailywire.com/news/19063/house-judiciary-committee-probe-comey-and-clintons-joseph-curl'
# link = 'http://countercurrentnews.info/2017/07/u-s-ally-saudi-arabia-is-about-to-behead-6-school-girls-for-acting-indecent-with-boys/'
# link = 'https://lewrockwell.com/2017/07/andrew-p-napolitano/president-trump-vs-department-justice/'
# link = 'http://www.charismanews.com/opinion/66520-ufos-appear-over-england-and-mexico'
# link = 'http://www.frontpagemag.com/fpm/267397/transgender-ban-isnt-fair-neither-war-daniel-greenfield'
# link = 'http://www.dcclothesline.com/2017/07/27/justine-damond-shot-to-death-by-muslim-cop-because-she-slapped-police-car/'
# link = 'https://fellowshipoftheminds.com/2017/07/27/illegal-alien-living-in-new-york-arrested-for-raping-12-year-old-girl-multiple-times/'
# Junk:
# link = 'http://www.celebtricity.com/nicki-minaj-files-10m-lawsuit-against-remy-ma-for-using-her-voice-in-diss-song-on-itunes/'
# link = 'https://www.scoopwhoop.com/india-inhuman-rape-cases/#.6j9dfreps'
# link = 'http://yournewswire.com/fbi-hard-drives-wasserman-schultz/'
# link = 'http://awarenessact.com/fukushima-plant-set-to-release-770000-tons-of-highly-radioactive-water-material-into-ocean/'
# link = 'http://fromthetrenchesworldreport.com/27-rifles-swiped-littleton-smash-grab/203710'
# link = 'http://www.wakingtimes.com/2017/07/26/5-signs-may-nontraditional-shaman/'
# link = 'http://worldwidehealthy.com/health/she-ate-cucumber-every-day-for-a-month-and-she-then-reported-these-changes/'
# link = 'https://truthkings.com/video-common-core-official-3-x-4/'
# link = 'http://www.thetruthseeker.co.uk/?p=155257'
# link = 'http://ushealthyadvisor.com/just-donald-trump-declare-soros-national-security-threat-support/'
# link = 'https://www.ancient-code.com/painted-in-history-two-ufos-spotted-in-ancient-painting-of-jesus-christ/'
# link = 'http://www.collective-evolution.com/2017/07/27/a-fascinating-story-about-the-real-men-in-black-from-the-legend-ingo-swann/'
# Political:
# link = 'http://thelastlineofdefense.org/breaking-president-trump-wants-you-to-know-the-truth-about-agenda-21/'
# link = 'http://www.defenddemocracy.press/one-week-after-mosuls-liberation-horror-of-us-siege-continues-to-unfold/'
# link = 'https://www.advocate.com/politics/2017/7/24/donald-trump-blocks-rosie-odonnell-twitter'
# link = 'http://www.breitbart.com/big-government/2017/07/24/study-8471-cases-double-voting-uncovered-21-states/'
# link = 'https://www.counterpunch.org/2017/07/27/the-myth-of-american-exceptionalism/'
# link = 'http://dailycaller.com/2017/07/27/establishment-media-refuse-to-cover-house-it-scandal-rocking-democrats/'
# link = 'http://davidstockmanscontracorner.com/the-mother-of-all-melt-ups/'
# link = 'http://dennismichaellynch.com/legendary-voice-actress-dies-99/'
# link = 'http://www.economicnoise.com/2017/07/23/biotech-etfs-continue-dominate-momentum-rankings/'
# link = 'https://www.ecowatch.com/the-poison-papers-2465841261.html'
# link = 'https://www.emptywheel.net/2017/07/26/if-a-tech-amicus-falls-in-the-woods-but-rosemary-collyer-ignores-it-would-it-matter/'
# link = 'https://www.foreignpolicyjournal.com/2017/07/20/behind-the-jerusalem-attack-how-trump-and-netanyahu-pushed-palestinians-into-a-corner/'
# CLICKBAIT
# link = 'http://americablog.com/2017/07/cbo-gop-obamacare-repeal-22m-uninsured-13k-deductible-premiums-soar-older.html'
# link = 'http://americanlookout.com/rms-corruption-more-obama-officials-scrutinized-in-unmasking-probe-video/'
# link = 'https://www.americasfreedomfighters.com/2017/07/24/top-marine-general/'
# link = 'https://ihavethetruth.com/2017/07/24/postal-service-helped-hillary/'  
# link = 'http://www.patriotchronicle.com/videomillennials-criticism-generation-gone-mega-viral/'
# link = 'http://www.lifenews.com/2017/07/27/planned-parenthood-abortion-doc-on-washing-hands-is-that-a-new-standard/'
# link = 'http://eaglerising.com/45914/who-is-the-worlds-richest-man-not-bill-gates-anymore/'
# link = 'http://meanlefthook.com/2017/07/dck-pills-transgender-troops/'
# link = 'http://twitchy.com/dougp-3137/2017/07/27/go-get-em-subpoenas-to-start-flying-in-sarah-palins-lawsuit-after-nyt-smear-job/'
# link = 'http://www.occupyliberals.com/2017/07/02/trump-rants-beating-cnn-guy-loony-sunday-morning-tweet/'
# link = 'https://politicalcult.com/veteran-obliterates-hollywood/'
# link = 'http://www.qpolitical.com/christian-church-america-changes-sunday-service-leads-congregation-muslim-ritual-praying-allah/'
# link = 'http://russia-insider.com/en/politics/us-evicts-rebel-group-wont-drop-fight-against-assad-syrian-base/ri20499'
# link = 'http://yournewswire.com/cia-propagandist-richest-man/'
# link = 'http://yournationnews.com/scientists-find-surprising-effect-red-wine-has-on-your-brain/'

# link = 'http://www.business2community.com/entertainment/chester-bennington-chris-cornell-murdered-cover-pedophile-ring-fake-news-01885695#4UUGizLgaK6MJKfl.97'
link = 'http://worldnewsdailyreport.com/rat-meat-sold-as-chicken-wings-fda-issues-warning-before-super-bowl/'
scraping(link)
# Out:
# URL********************************************************
# http://worldnewsdailyreport.com/rat-meat-sold-as-chicken-wings-fda-issues-warning-before-super-bowl/
# TITLE********************************************************
#
# Rat Meat sold as chicken wings: FDA issues warning before Super Bowl
# DATE********************************************************
# None
# AUTHOR********************************************************
# Nancy
# ARTICLE********************************************************
# ...
