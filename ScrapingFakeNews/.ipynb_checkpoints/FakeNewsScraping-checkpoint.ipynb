# %%
import requests
from bs4 import BeautifulSoup


def get_websites(file):
    websites_file = open(file, "r")
    websites = websites_file.readlines()
    for website in websites:
        if (website):
            get_news_firstpage(website)
#             print (website)
        else:
            print("Ooops, can't get url from the txt file!")
        
def get_news_firstpage(link):
    link = 'http://' + link
    print (link)
    headers = {'user-agent' : 'Mozilla/5.0'}
    source = requests.get(link, headers = headers)
    if source.status_code == 200: 
        soup = BeautifulSoup(source.content, "lxml")
    else: 
        print ("Oops, the website can not be found!!!")
#     print (soup)
    
    for article in soup.findAll('article'):
#         print (article)
        href = article.find('a').get('href')
        if href.startswith('http'): # for activisitpost
            print (href)
        else:
            href = link + href
            print (href)
#         get_news_content(href)
 
def get_news_content(href):
    headers = {'user-agent' : 'Mozilla/5.0'}
    try:
        source = requests.get(href, headers = headers)
    except requests.exceptions.ConnectionError:
        source.status_code = "Connection refused"
    if source.status_code == 200: 
        soup = BeautifulSoup(source.content, "lxml")
        print ("\nTitle: \n")
        for title in soup.findAll('h1'):
            print (title.text)
        
        file = open(title.text + ".txt", "w")
        
#         print("\nArticle: \n")
        body = soup.body
        for article in body.findAll('p'):
#             print (article.text)
            if (article.text):
                file.write(article.text)
            else:
                file.write('\n\n')
        file.close()
    else: 
        print ("Oops, the web page can not be found!!!")
#     print (soup)
    
#     print ("\nImage: \n")
#     images = soup.findAll('figure')
#     print (images)
        
        
#     print ("\nPublished Time: \n")
#     for time in soup.findAll('time', {'class': 'entry-date published updated'}):
#         print (time.text + " ago")
        
#     print ("\nAuthor: \n")
#     for author in soup.findAll('b'):
#         print (author.text)
        
#     print ("\nAds: \n")
#     for ads in soup.findAll('div', {'class': 'rc-photo-scale'}):
#         print (ads)

file = 'Fake_website.txt'
get_websites(file)
# link = 'theonion.com'
# link = 'americannews.com'
# link = 'activistpost.com'
# link = 'thedailysheeple.com'
# link = 'waterfordwhispersnews.com'
# link = 'clickhole.com'
# link = 'thebeaverton.com'  #with some tab
# link = 'dailynewsbin.com' # not exist
# link = 'abcnews.com.co' #not aceptable 

# link = 'fakingnews.com'  #not able to
# link = 'usapoliticstoday.com' #not able to
# link = 'usherald.com'  #not able to
# link = 'borowitzreport.com'  #not able to
# link = 'satirewire.com'  #not able to
# link = 'theshovel.com.au' #not able to
# get_news_firstpage(link)
# Out:
# http://theonion.com
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      74
# ---> 75     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      76         af, socktype, proto, canonname, sa = res
#
# //anaconda/envs/py3k/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     742     addrlist = []
# --> 743     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     744         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     360         else:
# --> 361             conn.request(method, url, **httplib_request_kw)
#     362
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     162     def connect(self):
# --> 163         conn = self._new_conn()
#     164         self._prepare_conn(conn)
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     146             raise NewConnectionError(
# --> 147                 self, "Failed to establish a new connection: %s" % e)
#     148
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x1127ffb38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     362         if new_retry.is_exhausted():
# --> 363             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     364
#
# MaxRetryError: HTTPConnectionPool(host='theonion.com%0a', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x1127ffb38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-11-6f0a56d41664> in <module>()
#      79
#      80 file = 'Fake_website.txt'
# ---> 81 get_websites(file)
#      82 # link = 'theonion.com'
#      83 # link = 'americannews.com'
#
# <ipython-input-11-6f0a56d41664> in get_websites(file)
#       8     for website in websites:
#       9         if (website):
# ---> 10             get_news_firstpage(website)
#      11 #             print (website)
#      12         else:
#
# <ipython-input-11-6f0a56d41664> in get_news_firstpage(link)
#      17     print (link)
#      18     headers = {'user-agent' : 'Mozilla/5.0'}
# ---> 19     source = requests.get(link, headers = headers)
#      20     if source.status_code == 200:
#      21         soup = BeautifulSoup(source.content, "lxml")
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='theonion.com%0a', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x1127ffb38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
